# %% [markdown]
# # Introduction
#
# **Environment preparation**
#
# * Create Python environment
# ```
# python -m venv env-name
# ```
# * Run venv
# ```
# env-name\Scripts\Activate
# ```
# * Intall python packages
# ```
# pip install jupyter jupyterlab pandas matplotlib requests seaborn scipy scikit-learn
# ```
# * Run Jupyter lab
# ```
# jupyter lab
# ```
#
# **Jupyter lab**
#
# * Add code
# * Add text
# * Execute command
# * Shortcuts (a, b, dd, Ctrl+Enter, Shift+Enter, x, c, v)
#
#
#
# **Alternatives**
#
# * Google Colab ([Colaboratory](https://colab.research.google.com/))
# * Python scripts in VS Code

# %% [markdown]
# # Data processing
#
# Data source: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# Important attributes description:
# * SalePrice: The property's sale price in dollars. This is the target variable that you're trying to predict.
# * MSSubClass: The building class
# * BldgType: Type of dwelling
# * HouseStyle: Style of dwelling
# * OverallQual: Overall material and finish quality
# * OverallCond: Overall condition rating
# * YearBuilt: Original construction date
# * Heating: Type of heating
# * CentralAir: Central air conditioning
# * GrLivArea: Above grade (ground) living area square feet
# * BedroomAbvGr: Number of bedrooms above basement level
#
# ## Pandas tasks:
# * Load data
# * Standard data inspection (functions head(), tail(), describe(), isna(), shape)
# * Select one attribute to variable
#     - Series and numpy compatibility
# * dtype, index, columns
# * Data selection - [], loc, iloc
# * Data filtering and logical operators
# * Add new column to dataframe
# * Calculate new numberical attribute
# * Data selection - comparison and negation
# * Assign new values to selected rows from dataframe
# * Use .apply() for rows and single column
# * Use .groupby() for data aggregation

# %% [markdown]
# ## Import used packages

# %%
import pandas as pd # dataframes
import numpy as np # matrices and linear algebra
import matplotlib.pyplot as plt # plotting
import seaborn as sns # another matplotlib interface - styled and easier to use

# %% [markdown]
# ## The first step is to load the data into the Pandas DataFrame - in our case it is a csv file

# %%
df_full = pd.read_csv('zsu_cv1_data.csv', sep = ',')
df_full
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %% [markdown]
# ## We shloud take a look on the data after loading so we know that everything is OK

# %% [markdown]
# ### We will start with showing first/last N rows
# - There are several ways of doing that:
#     - name of the dataframe
#     - head()
#     - tail()

# %% [markdown]
# ### Show 5 first and last rows

# %%
df_full.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ### Show first 5 rows

# %%
df_full.head() #first 5 rows
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ### Show last 20 rows

# %%
df_full.tail(20) #show last 20 rows
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1440         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 1441         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1442         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1443         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1444         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1445         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1446         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1447         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1448         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 1449         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1450         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1451         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1452         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1453         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1454         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1440      9   2008        WD         Normal     191000
# 1441      5   2008        WD         Normal     149300
# 1442      4   2009        WD         Normal     310000
# 1443      5   2009        WD         Normal     121000
# 1444     11   2007        WD         Normal     179600
# 1445      5   2007        WD         Normal     129000
# 1446      4   2010        WD         Normal     157900
# 1447     12   2007        WD         Normal     240000
# 1448      5   2007        WD         Normal     112000
# 1449      8   2006        WD        Abnorml      92000
# 1450      9   2009        WD         Normal     136000
# 1451      5   2009       New        Partial     287090
# 1452      5   2006        WD         Normal     145000
# 1453      7   2006        WD        Abnorml      84500
# 1454     10   2009        WD         Normal     185000
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [20 rows x 81 columns]

# %% [markdown]
# ## If we want to know if there are any missing values, the isna() function may render useful

# %%
df_full.isna().sum().sort_values().head(20) #in reverse - ascendingFalse in function sort_values()
# Out:
# Id               0
# TotalBsmtSF      0
# Heating          0
# SaleCondition    0
# CentralAir       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# SaleType         0
# YrSold           0
# dtype: int64

# %% [markdown]
# ## We can show summary of common statistical characteristic of the data using the describe() function

# %%
df_full.describe() #df_full.describe(include='O')
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# ## Dataframe has several useful properties
#     - shape
#     - dtypes
#     - columns
#     - index

# %% [markdown]
# #### Row and column count

# %%
df_full.shape
# Out:
# (1460, 81)

# %% [markdown]
# #### Datatypes of columns

# %%
df_full.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# #### Column names

# %%
df_full.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# #### Row index values

# %%
df_full.index
# Out:
# RangeIndex(start=0, stop=1460, step=1)

# %% [markdown]
# ## We may want to work with just one column not the whole dataframe
# - We will select only the SalePrice columns and save it to another variable

# %%
df_full.SalePrice
price = df_full['SalePrice']

# %% [markdown]
# ## Columns are called Pandas Series - it shares a common API with Pandas DataFrame
# - Pandas is numpy-backed so we can use Series as standard numpy arrays without any issues using the .values property

# %%
price.values
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500])

# %% [markdown]
# ## e.g. find maximum price using Numpy and Pandas

# %%
df_full.SalePrice.max()
# Out:
# 755000

# %%
np.max(df_full.SalePrice.values)
# Out:
# 755000

# %% [markdown]
# ## Data filtering using Pandas DataFrame
# - There are several ways of filtering the data (similar logic to .Where() in C# or WHERE in SQL)
# - We usually work with two indexers - .loc[] and .iloc[]
#
# ### The .iloc[] indexer works with positional indexes - very close to the way of working with the raw arrays
# ### The .loc[] indexer works with column names and logical expressions

# %% [markdown]
# ### Select all rows and 3rd column of dataframe

# %%
df_full.iloc[:, 2]
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object

# %% [markdown]
# ### Select all rows and LAST column of dataframe

# %%
df_full.iloc[:,-1
            ]
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# ### Select rows 15 to 22 and all columns

# %%
df_full.iloc[15:23, :]
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 15  16          45       RM         51.0     6120   Pave   NaN      Reg
# 16  17          20       RL          NaN    11241   Pave   NaN      IR1
# 17  18          90       RL         72.0    10791   Pave   NaN      Reg
# 18  19          20       RL         66.0    13695   Pave   NaN      Reg
# 19  20          20       RL         70.0     7560   Pave   NaN      Reg
# 20  21          60       RL        101.0    14215   Pave   NaN      IR1
# 21  22          45       RM         57.0     7449   Pave  Grvl      Reg
# 22  23          20       RL         75.0     9742   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 15         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 16         Lvl    AllPub  ...        0    NaN    NaN        Shed     700
# 17         Lvl    AllPub  ...        0    NaN    NaN        Shed     500
# 18         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 19         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 20         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 21         Bnk    AllPub  ...        0    NaN  GdPrv         NaN       0
# 22         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# 15      7   2007        WD         Normal     132000
# 16      3   2010        WD         Normal     149000
# 17     10   2006        WD         Normal      90000
# 18      6   2008        WD         Normal     159000
# 19      5   2009       COD        Abnorml     139000
# 20     11   2006       New        Partial     325300
# 21      6   2007        WD         Normal     139400
# 22      9   2008        WD         Normal     230000
#
# [8 rows x 81 columns]

# %% [markdown]
# ### Select rows 15 to 22 and 3rd column

# %%
df_full.iloc[15:23, 2]
# Out:
# 15    RM
# 16    RL
# 17    RL
# 18    RL
# 19    RL
# 20    RL
# 21    RM
# 22    RL
# Name: MSZoning, dtype: object

# %% [markdown]
# ## Select only a subset of columns to a new dataframe
# - 'SalePrice','MSSubClass','BldgType','HouseStyle','OverallQual','OverallCond','YearBuilt','Heating','CentralAir','GrLivArea','BedroomAbvGr'

# %%
df = df_full.loc[:, ['SalePrice','MSSubClass','BldgType','HouseStyle','OverallQual','OverallCond','YearBuilt','Heating','CentralAir','GrLivArea','BedroomAbvGr']].copy()
df
# Out:
#       SalePrice  MSSubClass BldgType HouseStyle  OverallQual  OverallCond  \
# 0        208500          60     1Fam     2Story            7            5
# 1        181500          20     1Fam     1Story            6            8
# 2        223500          60     1Fam     2Story            7            5
# 3        140000          70     1Fam     2Story            7            5
# 4        250000          60     1Fam     2Story            8            5
# ...         ...         ...      ...        ...          ...          ...
# 1455     175000          60     1Fam     2Story            6            5
# 1456     210000          20     1Fam     1Story            6            6
# 1457     266500          70     1Fam     2Story            7            9
# 1458     142125          20     1Fam     1Story            5            6
# 1459     147500          20     1Fam     1Story            5            6
#
#       YearBuilt Heating CentralAir  GrLivArea  BedroomAbvGr
# 0          2003    GasA          Y       1710             3
# 1          1976    GasA          Y       1262             3
# 2          2001    GasA          Y       1786             3
# 3          1915    GasA          Y       1717             3
# 4          2000    GasA          Y       2198             4
# ...         ...     ...        ...        ...           ...
# 1455       1999    GasA          Y       1647             3
# 1456       1978    GasA          Y       2073             3
# 1457       1941    GasA          Y       2340             4
# 1458       1950    GasA          Y       1078             2
# 1459       1965    GasA          Y       1256             3
#
# [1460 rows x 11 columns]

# %% [markdown]
# ### Select only houses built in year 2000 or later

# %%
df.YearBuilt > 2000
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: YearBuilt, Length: 1460, dtype: bool

# %%
df.loc[df.YearBuilt > 2000, :]
# Out:
#       SalePrice  MSSubClass BldgType HouseStyle  OverallQual  OverallCond  \
# 0        208500          60     1Fam     2Story            7            5
# 2        223500          60     1Fam     2Story            7            5
# 6        307000          20     1Fam     1Story            8            5
# 11       345000          60     1Fam     2Story            9            5
# 13       279500          20     1Fam     1Story            7            5
# ...         ...         ...      ...        ...          ...          ...
# 1444     179600          20     1Fam     1Story            7            5
# 1451     287090          20     1Fam     1Story            8            5
# 1452     145000         180   TwnhsE       SLvl            5            5
# 1453      84500          20     1Fam     1Story            5            5
# 1454     185000          20     1Fam     1Story            7            5
#
#       YearBuilt Heating CentralAir  GrLivArea  BedroomAbvGr
# 0          2003    GasA          Y       1710             3
# 2          2001    GasA          Y       1786             3
# 6          2004    GasA          Y       1694             3
# 11         2005    GasA          Y       2324             4
# 13         2006    GasA          Y       1494             3
# ...         ...     ...        ...        ...           ...
# 1444       2004    GasA          Y       1422             3
# 1451       2008    GasA          Y       1578             3
# 1452       2005    GasA          Y       1072             2
# 1453       2006    GasA          Y       1140             3
# 1454       2004    GasA          Y       1221             2
#
# [364 rows x 11 columns]

# %%
df[df.YearBuilt > 2000]
# Out:
#       SalePrice  MSSubClass BldgType HouseStyle  OverallQual  OverallCond  \
# 0        208500          60     1Fam     2Story            7            5
# 2        223500          60     1Fam     2Story            7            5
# 6        307000          20     1Fam     1Story            8            5
# 11       345000          60     1Fam     2Story            9            5
# 13       279500          20     1Fam     1Story            7            5
# ...         ...         ...      ...        ...          ...          ...
# 1444     179600          20     1Fam     1Story            7            5
# 1451     287090          20     1Fam     1Story            8            5
# 1452     145000         180   TwnhsE       SLvl            5            5
# 1453      84500          20     1Fam     1Story            5            5
# 1454     185000          20     1Fam     1Story            7            5
#
#       YearBuilt Heating CentralAir  GrLivArea  BedroomAbvGr
# 0          2003    GasA          Y       1710             3
# 2          2001    GasA          Y       1786             3
# 6          2004    GasA          Y       1694             3
# 11         2005    GasA          Y       2324             4
# 13         2006    GasA          Y       1494             3
# ...         ...     ...        ...        ...           ...
# 1444       2004    GasA          Y       1422             3
# 1451       2008    GasA          Y       1578             3
# 1452       2005    GasA          Y       1072             2
# 1453       2006    GasA          Y       1140             3
# 1454       2004    GasA          Y       1221             2
#
# [364 rows x 11 columns]

# %% [markdown]
# ### Select only houses that don't use GasA for heating (try != and ~ operators)

# %%
df.loc[df.Heating != 'GasA', :]
# Out:
#       SalePrice  MSSubClass BldgType HouseStyle  OverallQual  OverallCond  \
# 69       225000          50     1Fam     1.5Fin            7            4
# 93       133900         190   2fmCon     2.5Unf            6            6
# 108      115000          50     1Fam     1.5Fin            5            7
# 155       79000          50     1Fam     1.5Fin            6            5
# 275      205000          50     1Fam     1.5Fin            7            7
# 313      375000          20     1Fam     1Story            7            5
# 342       87500          90   Duplex     1Story            3            4
# 417      239000          70     1Fam     2Story            6            6
# 514       96500          45     1Fam     1.5Unf            5            5
# 636       60000          30     1Fam     1Story            2            3
# 676       87000          70     1Fam     2Story            4            2
# 713      129000         190   2fmCon     1Story            4            5
# 735      163000          75     1Fam     2.5Unf            7            7
# 747      265979          70     1Fam     2Story            7            7
# 749       98000          50     1Fam     1.5Fin            4            3
# 814      116000          50     1Fam     1.5Fin            5            7
# 968       37900          50     1Fam     1.5Fin            3            6
# 985      125000         190   2fmCon     1Story            5            5
# 1000      82000          20     1Fam     1Story            3            3
# 1013      85000          30     1Fam     1Story            5            4
# 1090      92900          90   Duplex     1Story            3            4
# 1132     117500          70     1Fam     2Story            6            4
# 1144      80000         190   2fmCon     1.5Fin            4            4
# 1248     129500          75     1Fam     2.5Unf            6            5
# 1269     144000          50     1Fam     1.5Fin            5            5
# 1321      72500          20     1Fam     1Story            3            6
# 1328     256000          50     1Fam     1.5Fin            6            7
# 1337      52500          30     1Fam     1Story            4            4
# 1349     122000          70     1Fam     2Story            8            5
# 1387     136000          50     1Fam     1.5Fin            6            7
# 1412      90000          90   Duplex     1Story            4            5
# 1443     121000          30     1Fam     1.5Unf            6            6
#
#       YearBuilt Heating CentralAir  GrLivArea  BedroomAbvGr
# 69         1953    GasW          Y       2287             3
# 93         1910    GasW          N       2291             4
# 108        1919    GasW          N       1517             3
# 155        1924    Grav          N       1096             2
# 275        1925    GasW          N       1548             3
# 313        1965    GasW          Y       2036             3
# 342        1949    Wall          N       1040             2
# 417        1918    GasW          N       2624             4
# 514        1926    Grav          N        789             2
# 636        1936    Grav          N        800             1
# 676        1900    GasW          N       1774             4
# 713        1970    GasW          N        960             3
# 735        1914    GasW          N       1768             2
# 747        1880    GasW          N       2640             4
# 749        1945    Wall          N       1529             4
# 814        1918    GasW          Y       1250             3
# 968        1910    Grav          N        968             2
# 985        1950    GasW          N       1164             3
# 1000       1952    GasW          N        944             2
# 1013       1910    GasW          N       1022             2
# 1090       1950    Wall          N       1040             2
# 1132       1880    GasW          Y       2210             5
# 1144       1941    Grav          N        924             2
# 1248       1917    OthW          N       2058             3
# 1269       1958    GasW          Y       1524             3
# 1321       1949   Floor          N        720             2
# 1328       1920    GasW          Y       2792             5
# 1337       1941    Grav          N        693             2
# 1349       1872    OthW          N       2358             4
# 1387       1916    GasW          N       2526             5
# 1412       1949    Wall          N       1040             2
# 1443       1916    Grav          N        952             2

# %%
df.loc[~(df.Heating == 'GasA'), :]
# Out:
#       SalePrice  MSSubClass BldgType HouseStyle  OverallQual  OverallCond  \
# 69       225000          50     1Fam     1.5Fin            7            4
# 93       133900         190   2fmCon     2.5Unf            6            6
# 108      115000          50     1Fam     1.5Fin            5            7
# 155       79000          50     1Fam     1.5Fin            6            5
# 275      205000          50     1Fam     1.5Fin            7            7
# 313      375000          20     1Fam     1Story            7            5
# 342       87500          90   Duplex     1Story            3            4
# 417      239000          70     1Fam     2Story            6            6
# 514       96500          45     1Fam     1.5Unf            5            5
# 636       60000          30     1Fam     1Story            2            3
# 676       87000          70     1Fam     2Story            4            2
# 713      129000         190   2fmCon     1Story            4            5
# 735      163000          75     1Fam     2.5Unf            7            7
# 747      265979          70     1Fam     2Story            7            7
# 749       98000          50     1Fam     1.5Fin            4            3
# 814      116000          50     1Fam     1.5Fin            5            7
# 968       37900          50     1Fam     1.5Fin            3            6
# 985      125000         190   2fmCon     1Story            5            5
# 1000      82000          20     1Fam     1Story            3            3
# 1013      85000          30     1Fam     1Story            5            4
# 1090      92900          90   Duplex     1Story            3            4
# 1132     117500          70     1Fam     2Story            6            4
# 1144      80000         190   2fmCon     1.5Fin            4            4
# 1248     129500          75     1Fam     2.5Unf            6            5
# 1269     144000          50     1Fam     1.5Fin            5            5
# 1321      72500          20     1Fam     1Story            3            6
# 1328     256000          50     1Fam     1.5Fin            6            7
# 1337      52500          30     1Fam     1Story            4            4
# 1349     122000          70     1Fam     2Story            8            5
# 1387     136000          50     1Fam     1.5Fin            6            7
# 1412      90000          90   Duplex     1Story            4            5
# 1443     121000          30     1Fam     1.5Unf            6            6
#
#       YearBuilt Heating CentralAir  GrLivArea  BedroomAbvGr
# 69         1953    GasW          Y       2287             3
# 93         1910    GasW          N       2291             4
# 108        1919    GasW          N       1517             3
# 155        1924    Grav          N       1096             2
# 275        1925    GasW          N       1548             3
# 313        1965    GasW          Y       2036             3
# 342        1949    Wall          N       1040             2
# 417        1918    GasW          N       2624             4
# 514        1926    Grav          N        789             2
# 636        1936    Grav          N        800             1
# 676        1900    GasW          N       1774             4
# 713        1970    GasW          N        960             3
# 735        1914    GasW          N       1768             2
# 747        1880    GasW          N       2640             4
# 749        1945    Wall          N       1529             4
# 814        1918    GasW          Y       1250             3
# 968        1910    Grav          N        968             2
# 985        1950    GasW          N       1164             3
# 1000       1952    GasW          N        944             2
# 1013       1910    GasW          N       1022             2
# 1090       1950    Wall          N       1040             2
# 1132       1880    GasW          Y       2210             5
# 1144       1941    Grav          N        924             2
# 1248       1917    OthW          N       2058             3
# 1269       1958    GasW          Y       1524             3
# 1321       1949   Floor          N        720             2
# 1328       1920    GasW          Y       2792             5
# 1337       1941    Grav          N        693             2
# 1349       1872    OthW          N       2358             4
# 1387       1916    GasW          N       2526             5
# 1412       1949    Wall          N       1040             2
# 1443       1916    Grav          N        952             2

# %% [markdown]
# ### Select houses cheaper than 180k USD and with at least 2 bedrooms

# %%
df.loc[(df.SalePrice < 180000) & (df.BedroomAbvGr > 2), :]
# Out:
#       SalePrice  MSSubClass BldgType HouseStyle  OverallQual  OverallCond  \
# 3        140000          70     1Fam     2Story            7            5
# 10       129500          20     1Fam     1Story            5            5
# 18       159000          20     1Fam     1Story            5            5
# 19       139000          20     1Fam     1Story            5            6
# 21       139400          45     1Fam     1.5Unf            7            7
# ...         ...         ...      ...        ...          ...          ...
# 1446     157900          20     1Fam     1Story            5            7
# 1450     136000          90   Duplex     2Story            5            5
# 1453      84500          20     1Fam     1Story            5            5
# 1455     175000          60     1Fam     2Story            6            5
# 1459     147500          20     1Fam     1Story            5            6
#
#       YearBuilt Heating CentralAir  GrLivArea  BedroomAbvGr
# 3          1915    GasA          Y       1717             3
# 10         1965    GasA          Y       1040             3
# 18         2004    GasA          Y       1114             3
# 19         1958    GasA          Y       1339             3
# 21         1930    GasA          Y       1108             3
# ...         ...     ...        ...        ...           ...
# 1446       1962    GasA          Y       1188             3
# 1450       1974    GasA          Y       1792             4
# 1453       2006    GasA          Y       1140             3
# 1455       1999    GasA          Y       1647             3
# 1459       1965    GasA          Y       1256             3
#
# [590 rows x 11 columns]

# %% [markdown]
# ### Select houses with 2 stories or air conditioning

# %%
df.loc[(df.AirConditioning== 2) | (df.Stories == 2), :]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_20673/1564210378.py in <module>
# ----> 1 df.loc[(df.AirConditioning== 2) | (df.Stories == 2), :]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'AirConditioning'

# %% [markdown]
# ## We can add new columns to the DataFrame as well

# %% [markdown]
# ### Add a new column named Age for each house (current year - year built)

# %%
df['Age'] = 2021- df.YearBuilt
df.head()
# Out:
#    SalePrice  MSSubClass BldgType HouseStyle  OverallQual  OverallCond  \
# 0     208500          60     1Fam     2Story            7            5
# 1     181500          20     1Fam     1Story            6            8
# 2     223500          60     1Fam     2Story            7            5
# 3     140000          70     1Fam     2Story            7            5
# 4     250000          60     1Fam     2Story            8            5
#
#    YearBuilt Heating CentralAir  GrLivArea  BedroomAbvGr  Age
# 0       2003    GasA          Y       1710             3   18
# 1       1976    GasA          Y       1262             3   45
# 2       2001    GasA          Y       1786             3   20
# 3       1915    GasA          Y       1717             3  106
# 4       2000    GasA          Y       2198             4   21

# %% [markdown]
# ### Add a new column IsLuxury with True value for houses with more than 3 bedrooms and price above 214k USD (.loc)
# - How many luxury houses are in the dataset?

# %%
df.loc[:, 'IsLuxury'] = False
df.loc[(df.BedroomAbvGr > 3) & (df.SalePrice > 214000), 'IsLuxury'] = True
df.head()
# Out:
#    SalePrice  MSSubClass BldgType HouseStyle  OverallQual  OverallCond  \
# 0     208500          60     1Fam     2Story            7            5
# 1     181500          20     1Fam     1Story            6            8
# 2     223500          60     1Fam     2Story            7            5
# 3     140000          70     1Fam     2Story            7            5
# 4     250000          60     1Fam     2Story            8            5
#
#    YearBuilt Heating CentralAir  GrLivArea  BedroomAbvGr  Age  IsLuxury
# 0       2003    GasA          Y       1710             3   18     False
# 1       1976    GasA          Y       1262             3   45     False
# 2       2001    GasA          Y       1786             3   20     False
# 3       1915    GasA          Y       1717             3  106     False
# 4       2000    GasA          Y       2198             4   21      True

# %% [markdown]
# ### BONUS: We may apply function to each row of the dataset and compute the value that way as well

# %% [markdown]
# ## Pandas enables us to use aggregation functions for the data using the .groupby() function

# %% [markdown]
# ### Compute counts for all the heating methods (groupby / value_counts)

# %%
df.groupby('Heating').Heating.count()
# Out:
# Heating
# Floor       1
# GasA     1428
# GasW       18
# Grav        7
# OthW        2
# Wall        4
# Name: Heating, dtype: int64

# %%
df.Heating.value_counts()
# Out:
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Scatter plot
# - Visualize relationship between SalePrice and GrLivArea.Use scatter plot from **Matplotlib**.

# %%
plt.scatter(df.SalePrice, df.GrLivArea)

# %% [markdown]
# ### Modify figure size and add title

# %%
fig = plt.figure(figsize=(9,6))
plt.scatter(df.SalePrice, df.GrLivArea)
plt.title('Relationship between price and living area')
plt.show()

# %% [markdown]
# ### Add axis labels

# %%
fig = plt.figure(figsize=(9,6))
plt.scatter(df.SalePrice, df.GrLivArea)
plt.title('Relationship between price and living area')
plt.xlabel('Price')
plt.ylabel('Living area')
plt.show()

# %% [markdown]
# ### Modify one of axis to logaritmic scale

# %%
fig = plt.figure(figsize=(9,6))
plt.scatter(df.SalePrice, df.GrLivArea)
plt.title('Relationship between price and living area')
plt.xlabel('Price')
plt.ylabel('Living area')
plt.xscale('log')
plt.show()

# %% [markdown]
# ### Add colors for data points based on CentralAir value.

# %%
#next lab

# %% [markdown]
# ### Try to use scatterplot from **Seaborn** library for scatter plot visualization.

# %% [markdown]
# #### Use series data for axes x and y

# %%
sns.scatterplot(date=df.SalePrice, yzdf.GrLivArea)
# Out:
#   File "/tmp/ipykernel_20673/2484039140.py", line 1
#     sns.scatterplot(date=df.SalePrice, yzdf.GrLivArea)
#                                        ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ### Use dataframe as source and column names for axes data

# %%
sns.scatterplot(data=df, x='SalePrice', y='GrLivArea')
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='GrLivArea'>

# %% [markdown]
# ### Resize plot and add color for markers based on CentralAir column

# %%
sns.scatterplot(data=df, x='SalePrice', y='GrLivArea', hue='CentralAir')
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='GrLivArea'>

# %% [markdown]
# ### Set color palette to *binary* scheme

# %%
sns.scatterplot(data=df, x='SalePrice', y='GrLivArea', hue='CentralAir', palette='binary')
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='GrLivArea'>

# %% [markdown]
# ## Line plot
# - Calculate and vizualize average house price in relationship to YearBuild.

# %%
agg = df.groupby('YearBuilt').SalePrice.mean()
agg
# Out:
# YearBuilt
# 1872    122000.000000
# 1875     94000.000000
# 1880    200619.750000
# 1882    168000.000000
# 1885    111250.000000
#             ...
# 2006    251775.447761
# 2007    255362.734694
# 2008    348849.130435
# 2009    269220.000000
# 2010    394432.000000
# Name: SalePrice, Length: 112, dtype: float64

# %%
plt.plot(agg.index, agg.values)

# %% [markdown]
# ### Create dataframe from the previous calculation and vizualize using Seaborn line plot (note: use .reset_index())

# %%
df_agg = agg.reset_index()
df_agg
# Out:
#      YearBuilt      SalePrice
# 0         1872  122000.000000
# 1         1875   94000.000000
# 2         1880  200619.750000
# 3         1882  168000.000000
# 4         1885  111250.000000
# ..         ...            ...
# 107       2006  251775.447761
# 108       2007  255362.734694
# 109       2008  348849.130435
# 110       2009  269220.000000
# 111       2010  394432.000000
#
# [112 rows x 2 columns]

# %%
sns.lineplot(data=df_agg, x='YearBuilt', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %% [markdown]
# ## Bar plot
# - Calculate and vizualize how many of houses have CentralAir
# - Use Barplot for visualization

# %%
series = df.groupby('CentralAir').CentralAir.count()
series

# %%
plt.bar(x=series.index, height=series.values)

# %% [markdown]
# ### Vizualize number of building type and if they contains air conditioning using Seaborn

# %%
df_agg = df.groupby(['HouseStyle', 'CentralAir']).CentralAir.count().reset_index(name='Count')
df_agg
# Out:
#    HouseStyle CentralAir  Count
# 0      1.5Fin          N     18
# 1      1.5Fin          Y    136
# 2      1.5Unf          N      4
# 3      1.5Unf          Y     10
# 4      1Story          N     41
# 5      1Story          Y    685
# 6      2.5Fin          N      1
# 7      2.5Fin          Y      7
# 8      2.5Unf          N      7
# 9      2.5Unf          Y      4
# 10     2Story          N     24
# 11     2Story          Y    421
# 12     SFoyer          Y     37
# 13       SLvl          Y     65

# %%
sns.barplot(data=df_agg, y='HouseStyle', x='Count', hue='CentralAir')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='HouseStyle'>

# %% [markdown]
# # Tasks
# ## Pandas (1 pt)
# Add a new column *Undervalued* which is set to True in case that the house is priced bellow 163k USD and has both OverallQual and OverallCond higher than 5.
#
# How many undervalued houses are in the dataset?
#
# ## Vizualization (1 pt)
# Add to dataframe new attribute determining if the house was build before or after year 2000.
#
# Create bar chart for number of houses depending on type of dwelling (attribute BldgType, use as a category axis) and added binary attribute about house age (use as a bar color).

# %%
# df['Undervalued'] = False
# df.loc[(df['SalePrice'] < 163000) & ((df['OverallQual'] > 5) & (df['OverallCond'] >= 5)), 'Undervalued'] = True
# df.loc[df['Undervalued'] == True]

# %%
# df['After2000'] = False
# df.loc[df['YearBuilt'] > 2000, 'After2000'] = True 
# df.loc[df['After2000'] == True]

#TODO
